# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandini1230/module3/blob/main/Module3_Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5973 sha256=dcfe9655cde998d81b89f4ae9afc24591ab32e763610a8bca42c3eb80ff54d5c
#   Stored in directory: /root/.cache/pip/wheels/1b/02/6c/a45230be8603bd95c0a51cd2b289aefdd860c1a100eab73661
# Successfully built apyori
# ...

# %%
# importing required datasets
import numpy as np
import pandas as pd
from apyori import apriori

# %%
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-1dfbfaba-6ad2-4862-873f-50c7a1480c7f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1dfbfaba-6ad2-4862-873f-50c7a1480c7f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# load the dataset
store_data=pd.read_csv("day1.csv")

# %%
store_data #having a glance at the data
# Out:
#     wine  chips  bread  butter   Milk  Apple
# 0   wine    NaN  bread  butter   Milk  Apple
# 1    NaN    NaN  bread  butter   Milk    NaN
# 2    NaN  chips    NaN      NaN   NaN  Apple
# 3   wine  chips  bread  butter   Milk  Apple
# 4   wine  chips    NaN      NaN  Milk    NaN
# 5   wine  chips  bread  butter   Milk  Apple
# 6   wine  chips    NaN      NaN  Milk    NaN
# 7   wine  chips  bread      NaN   NaN  Apple
# 8    NaN    NaN  bread  butter   Milk  Apple
# 9   wine    NaN  bread  butter    NaN  Apple
# 10  wine  chips  bread  butter   Milk    NaN
# 11  wine    NaN  bread  butter   Milk  Apple
# 12  wine  chips  bread      NaN  Milk  Apple
# 13   NaN    NaN  bread  butter   Milk  Apple
# 14   NaN    NaN  bread  butter   Milk  Apple
# 15  wine  chips  bread  butter   Milk  Apple
# 16  wine  chips  bread  butter   Milk  Apple
# 17  wine  chips    NaN  butter   Milk  Apple
# 18  wine    NaN  bread  butter   Milk  Apple
# 19  wine  chips  bread  butter    NaN  Apple
# ...

# %%
store_data.shape
# Out:
# (21, 6)

# %%
# converting the pandas dataframe into a list of lists
records=[]
for i in range(0,21):
  records.append([str(store_data.values[i,j]) for j in range(0,6)])

# %%
# building the first apriori model
association_rules=apriori(records,min_support=0.5,min_confidence=0.7,min_lift=1.2,min_lenght=2)
association_results=list(association_rules)

# %%
# getting the number of rules
print(len(association_results))
# Out:
# 6

# %%
# glancing at the first rules
print(association_results)
# Out:
# [RelationRecord(items=frozenset({'bread', 'butter '}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bread'}), items_add=frozenset({'butter '}), confidence=0.875, lift=1.2249999999999999), OrderedStatistic(items_base=frozenset({'butter '}), items_add=frozenset({'bread'}), confidence=0.9333333333333332, lift=1.2249999999999999)]), RelationRecord(items=frozenset({'Milk', 'bread', 'Apple'}), support=0.5238095238095238, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Milk', 'Apple'}), items_add=frozenset({'bread'}), confidence=0.9166666666666667, lift=1.2031250000000002)]), RelationRecord(items=frozenset({'Milk', 'butter ', 'Apple'}), support=0.5238095238095238, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter '}), items_add=frozenset({'Milk', 'Apple'}), confidence=0.7333333333333334, lift=1.2833333333333334), OrderedStatistic(items_base=frozenset({'Milk', 'Apple'}), items_add=frozenset({'butter '}), confidence=0.916
# ...
